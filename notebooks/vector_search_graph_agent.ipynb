# %% [markdown]
# # Vector Search Graph Agent Demo

# %%
import sys
sys.path.append("../")

from dotenv import load_dotenv

load_dotenv()

from src.ps_genai_agents.agents.graph.vector_search.vector_search import create_vector_search_graph_agent

# %%
agent = create_vector_search_graph_agent()

# %%
from IPython.display import Image

Image(agent.get_graph().draw_png())

# %%
res = agent.invoke(
    {
        "input": "What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?",
        "chat_history": [],
    }
)
# Out:
# > run_agent
# initial data:  {'input': 'What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?', 'sub_questions': None, 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'sources': None, 'context': None}
# tool='Neo4jVectorSearch' tool_input={'query': 'total responses under seat23 for Honda Civic'} log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'total responses under seat23 for Honda Civic'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})] tool_call_id='call_8KfdCWLClrvADeWvdzuoIVcn'
# tool='Neo4jVectorSearch' tool_input={'query': 'male to female proportion for responses under seat23 for Honda Civic'} log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'male to female proportion for responses under seat23 for Honda Civic'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})] tool_call_id='call_4WPEezcgI8DEj6dlYu8Sq48J'
# tool='Neo4jVectorSearch' tool_input={'query': 'problem for seat23 in Honda Civic'} log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'problem for seat23 in Honda Civic'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})] tool_call_id='call_HY3M2k9Pf1xJnZ8M6ychdnYO'
# > router
# > vector search node
# agent action:  3 [ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'total responses under seat23 for Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'total responses under seat23 for Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})], tool_call_id='call_8KfdCWLClrvADeWvdzuoIVcn'), ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'male to female proportion for responses under seat23 for Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'male to female proportion for responses under seat23 for Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})], tool_call_id='call_4WPEezcgI8DEj6dlYu8Sq48J'), ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'problem for seat23 in Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'problem for seat23 in Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdz ...
# > router
# > vector search node
# agent action:  2 [ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'male to female proportion for responses under seat23 for Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'male to female proportion for responses under seat23 for Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})], tool_call_id='call_4WPEezcgI8DEj6dlYu8Sq48J'), ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'problem for seat23 in Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'problem for seat23 in Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})], tool_call_id='call_HY3M2k9Pf1xJnZ8M6ychdnYO')]
# > router
# > vector search node
# agent action:  1 [ToolAgentAction(tool='Neo4jVectorSearch', tool_input={'query': 'problem for seat23 in Honda Civic'}, log="\nInvoking: `Neo4jVectorSearch` with `{'query': 'problem for seat23 in Honda Civic'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'function': {'arguments': '{"query": "total responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'function': {'arguments': '{"query": "male to female proportion for responses under seat23 for Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}, {'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'function': {'arguments': '{"query": "problem for seat23 in Honda Civic"}', 'name': 'Neo4jVectorSearch'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 218, 'total_tokens': 312, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48939e43-dfba-47d2-abdc-6b55c2ac1bef-0', tool_calls=[{'name': 'Neo4jVectorSearch', 'args': {'query': 'total responses under seat23 for Honda Civic'}, 'id': 'call_8KfdCWLClrvADeWvdzuoIVcn', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'male to female proportion for responses under seat23 for Honda Civic'}, 'id': 'call_4WPEezcgI8DEj6dlYu8Sq48J', 'type': 'tool_call'}, {'name': 'Neo4jVectorSearch', 'args': {'query': 'problem for seat23 in Honda Civic'}, 'id': 'call_HY3M2k9Pf1xJnZ8M6ychdnYO', 'type': 'tool_call'}], usage_metadata={'input_tokens': 218, 'output_tokens': 94, 'total_tokens': 312})], tool_call_id='call_HY3M2k9Pf1xJnZ8M6ychdnYO')]
# > router
# > final_answer
# {'input': 'What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?', 'sub_questions': ['problem for seat23 in Honda Civic'], 'chat_history': [], 'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'{\'result\': [RetrieverResultItem(content="{\'id\': \'96A2278Y\', \'verbatim\': \'Anybody over 6ft is sitting tight in the seat.\'}", metadata={\'score\': 0.924701452255249, \'id\': \'96A2278Y\'}), RetrieverResultItem(content="{\'id\': \'93398758\', \'verbatim\': \'i am a very short person, seems like th-e height adjustment does not go high enough and then seems to push you in a forward seating positon.\'}", metadata={\'score\': 0.9237664341926575, \'id\': \'93398758\'}), RetrieverResultItem(content="{\'id\': \'9354742H\', \'verbatim\': \'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.\'}", metadata={\'score\': 0.9237554669380188, \'id\': \'9354742H\'})]}', 'Neo4jVectorSearch'}, {'{\'result\': [RetrieverResultItem(content="{\'id\': \'96A2278Y\', \'verbatim\': \'Anybody over 6ft is sitting tight in the seat.\'}", metadata={\'score\': 0.9191662669181824, \'id\': \'96A2278Y\'}), RetrieverResultItem(content="{\'id\': \'9354742H\', \'verbatim\': \'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.\'}", metadata={\'score\': 0.9165725708007812, \'id\': \'9354742H\'}), RetrieverResultItem(content="{\'id\': \'978473A7\', \'verbatim\': \'Slider\'}", metadata={\'score\': 0.9156064391136169, \'id\': \'978473A7\'})]}', 'Neo4jVectorSearch'}, {'{\'result\': [RetrieverResultItem(content="{\'id\': \'9354742H\', \'verbatim\': \'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.\'}", metadata={\'score\': 0.9356828927993774, \'id\': \'9354742H\'}), RetrieverResultItem(content=\'{\\\'id\\\': \\\'9764779E\\\', \\\'verbatim\\\': "The seat only goes so far back. I know it\\\'s a smaller vehicle, but the range just isn\\\'t enough."}\', metadata={\'score\': 0.933993935585022, \'id\': \'9764779E\'}), RetrieverResultItem(content="{\'id\': \'96A2278Y\', \'verbatim\': \'Anybody over 6ft is sitting tight in the seat.\'}", metadata={\'score\': 0.9313228130340576, \'id\': \'96A2278Y\'})]}', 'Neo4jVectorSearch'}], 'sources': ['96A2278Y', '93398758', '9354742H', '96A2278Y', '9354742H', '978473A7', '9354742H', '9764779E', '96A2278Y'], 'context': ["{'id': '96A2278Y', 'verbatim': 'Anybody over 6ft is sitting tight in the seat.'}", "{'id': '93398758', 'verbatim': 'i am a very short person, seems like th-e height adjustment does not go high enough and then seems to push you in a forward seating positon.'}", "{'id': '9354742H', 'verbatim': 'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.'}", "{'id': '96A2278Y', 'verbatim': 'Anybody over 6ft is sitting tight in the seat.'}", "{'id': '9354742H', 'verbatim': 'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.'}", "{'id': '978473A7', 'verbatim': 'Slider'}", "{'id': '9354742H', 'verbatim': 'The roofline of the car is fairly short. Making it harder for taller people to sit in the passenger seat because it does not have height adjustment.'}", '{\'id\': \'9764779E\', \'verbatim\': "The seat only goes so far back. I know it\'s a smaller vehicle, but the range just isn\'t enough."}', "{'id': '96A2278Y', 'verbatim': 'Anybody over 6ft is sitting tight in the seat.'}"]}

# %%
res["agent_outcome"].display()
# Out:
# Question:
# What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?
#
# Sub Questions:
# problem for seat23 in Honda Civic
#
#
# Vector Search Source IDs:
# ['96A2278Y', '93398758', '9354742H', '96A2278Y', '9354742H', '978473A7', '9354742H', '9764779E', '96A2278Y']
#
# Vector Search Summary:
# None
#
# Final Response:
# - Total responses under seat23 for Honda Civic: 9
# - Male to female proportion: Not provided
# - Problem for seat23:
#   - Taller individuals (over 6ft) find the seat tight.
#   - Short individuals find the height adjustment insufficient and pushing them forward.
#   - The roofline is low, making it difficult for taller passengers without height adjustment.
#   - The seat's range of backward adjustment is limited.
