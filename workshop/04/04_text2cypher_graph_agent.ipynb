# %% [markdown]
# # Professional Services Retreat | GenAI Workshop

# %% [markdown]
# # Text2Cypher Graph Agent Demo

# %% [markdown]
# This notebook demonstrates how build and use a Text2Cypher graph agent.

# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.append("../../")

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.graphs import Neo4jGraph

load_dotenv()

from src.ps_genai_agents.agents.graph.text2cypher import create_text2cypher_graph_agent

(
    print(".env variables loaded!")
    if load_dotenv()
    else print("Unable to load .env variables.")
)
# Out:
# .env variables loaded!

# %% [markdown]
# ## LLM Connection

# %% [markdown]
# The LLM we define here will be responsible for generating Cypher and summarizing the returned query results. In custom implementations you may decide to let different LLMs handle different tasks. Perhaps you can summarize with a lower-performance LLM in order to lower your application costs.

# %%
llm = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# ## Graph Connection

# %% [markdown]
# The LangChain `Neo4jGraph` class will be used to connect to our Aura instance. It will be used to automatically gather the graph schema and read from the database.

# %%
graph = Neo4jGraph(
    url=os.environ.get("IQS_NEO4J_URI"),
    username=os.environ.get("IQS_NEO4J_USERNAME"),
    password=os.environ.get("IQS_NEO4J_PASSWORD"),
    refresh_schema=True,
)

# %% [markdown]
# ## Example Queries

# %% [markdown]
# We store our queries in a yaml file. This allows us to easily store and modify our queries.

# %%
QUERY_LOCATION = "../../data/iqs/queries/queries.yml"

# %% [markdown]
# ## Construct Agent

# %% [markdown]
# Now we can use the `ps-genai-agent` function to construct a Text2Cypher agent.

# %%
agent = create_text2cypher_graph_agent(chat_llm=llm, neo4j_graph=graph, example_queries_location=QUERY_LOCATION)

# %% [markdown]
# ### Architecture

# %% [markdown]
# Let's take a look at the architecture of our agent. You will need `Graphviz` installed to visualize the architecture with the below code. It should be identical to the below image.

# %%
# from IPython.display import Image
# Image(agent.get_graph().draw_png())

# %% [markdown]
# We see that there are four nodes in our architecture
# * agent
#   * This is the input node. At this step the user's question is broken into subquestions and it's decided whether the question is in scope.
# * text2cypher
#   * This node will generate a cypher query for the given question or subquestion and run it against the database.
#   * Results are gathered in the `state`.
# * error
#   * This node will either explain why the agent can't answer a question or summarize any results that the agent has gathered so far.
# * final_answer
#   * This node will return a `Response` object containing the information gathered during the request.
#
#
#
# There are two types of relationships in our architecture
# * conditional edges
#   * These edges exist where a node may have many options for the next action. The LLM decides which path shuold be taken.
# * regular edges
#   * These edges exist where only a single path is defined.

# %% [markdown]
# ![text2cypher-graph-architecture](./images/text2cypher-graph-agent.png)

# %% [markdown]
# ### Nodes

# %% [markdown]
# Each node outputs a dictionary with keys that map to attributes in the `state`. Only attributes that should be modified need to be provided in the `return` statement.

# %% [markdown]
# ```Python
# def text2cypher_node(data: Dict[str, Any]) -> Dict[str, Any]:
#
#     agent_action = data.get("agent_outcome")
#     intermediate_steps = list()
#
#     tool_params = agent_action[0].tool_input
#
#     output = execute_text2cypher(tool_params)
#     intermediate_steps.append(output["intermediate_steps"][0])
#     agent_outcome = (
#         agent_action[1:]
#         if len(agent_action) > 1
#         else [
#             AgentAction(
#                 tool="final_answer",
#                 tool_input="",
#                 log="No more actions to perform. Moving to summarization step.",
#             )
#         ]
#     )
#
#     return {
#         "agent_outcome": agent_outcome,
#         "intermediate_steps": intermediate_steps,
#         "cypher": output.get("cypher"),
#         "cypher_result": output.get("cypher_result"),
#     }
# ```

# %% [markdown]
# ### State

# %% [markdown]
# The state variable is passed to each node and informs which action should be taken. Different agents will likely have different states. For example the vector search agent will have an attribute for tracking node source IDs for citations.
#
# We annotate attributes with `operator.add` to inform `LangGraph` that new values should be appended to the list, not replace the previous values. This allows us to track results from multi-hop workflows.

# %% [markdown]
# ```python
# class AgentState(TypedDict):
#     # The input string
#     input: str
#     # The sub questions identified in the user input
#     sub_questions: Annotated[Union[List[str], None], operator.add]
#     # The list of previous messages in the conversation
#     chat_history: list[BaseMessage]
#     # The outcome of a given call to the agent
#     # Needs `None` as a valid type, since this is what this will start as
#     agent_outcome: Union[AgentAction, AgentFinish, None]
#     # List of actions and corresponding observations
#     # Here we annotate this with `operator.add` to indicate that operations to
#     # this state should be ADDED to the existing values (not overwrite it)
#     intermediate_steps: Annotated[list[tuple[AgentAction, str]], operator.add]
#     # The cypher query ran
#     cypher: Annotated[Union[List[str], None], operator.add]
#     # The result of the cypher query
#     cypher_result: Annotated[Union[List[Any], None], operator.add]
# ```

# %% [markdown]
# ## Questions

# %%
res = agent.invoke(
    {
        "input": "What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?",
        "chat_history": [],
    }
)
# Out:
# > run_agent
# initial data:  {'input': 'What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?', 'sub_questions': None, 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'cypher': None, 'cypher_result': None}
# tool='Text2Cypher' tool_input={'query': 'What are the total responses under seat23 for Honda Civic?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What are the total responses under seat23 for Honda Civic?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_FCbUUCsARZmGNS0ieZ21T9gB'
# tool='Text2Cypher' tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'
# tool='Text2Cypher' tool_input={'query': 'What is the problem for seat23?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ'
# > router
# next action:  tool='Text2Cypher' tool_input={'query': 'What are the total responses under seat23 for Honda Civic?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What are the total responses under seat23 for Honda Civic?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_FCbUUCsARZmGNS0ieZ21T9gB'
# Text2Cypher
# {'agent_outcome': [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What are the total responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What are the total responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_FCbUUCsARZmGNS0ieZ21T9gB'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'to ...
# > text2cypher node
# agent action:  3 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What are the total responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What are the total responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_FCbUUCsARZmGNS0ieZ21T9gB'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'too ...
# params:  {'query': 'What are the total responses under seat23 for Honda Civic?'}
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the total responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses\\nRETURN totalResponses, problem\\n\'}]}'}], 'cypher': ['cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses\nRETURN totalResponses, problem\n'], 'cypher_result': [{'totalResponses': 10, 'problem': 'SEAT23: Seat materials scuff/soil easily'}]}
#
# > router
# next action:  tool='Text2Cypher' tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'
# Text2Cypher
# {'agent_outcome': [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the total responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"} ...
# > text2cypher node
# agent action:  2 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_k7aZJs6nq5jYctuTs7JwqkVc'), ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ')]
# params:  {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What is the male to female proportion for responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'males\': 7, \'females\': 3, \'maleToFemaleRatio\': 2.3333333333333335, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \\nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\\n\'}]}'}], 'cypher': ['cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\n'], 'cypher_result': [{'totalResponses': 10, 'males': 7, 'females': 3, 'maleToFemaleRatio': 2.3333333333333335, 'problem': 'SEAT23: Seat materials scuff/soil easily'}]}
#
# > router
# next action:  tool='Text2Cypher' tool_input={'query': 'What is the problem for seat23?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})] tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ'
# Text2Cypher
# {'agent_outcome': [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the total responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses\\nRETURN totalResponses, problem\\n\'}]}'}, {'Text2Cypher', '{\'query\': \'What is the male to female proportion for responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'males\': 7, \'females\': 3, \'maleToFemaleRatio\': 2.3333333333333335, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \\nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\\n\'}]}'}], 'cypher': ['cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses\nRETURN totalResponses, problem\n', 'cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\n'], 'cypher_result': [{'totalResponses': 10, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'totalResponses': 10, 'males': 7, 'females': 3, 'maleToFemaleRatio': 2.3333333333333335, 'problem': 'SEAT23: Seat materials scuff/soil easily'}], 'input': 'What are the total responses under seat23 for honda civic, what is the male t ...
# > text2cypher node
# agent action:  1 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What is the problem for seat23?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What is the problem for seat23?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'function': {'arguments': '{"query": "What are the total responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'function': {'arguments': '{"query": "What is the male to female proportion for responses under seat23 for Honda Civic?"}', 'name': 'Text2Cypher'}, 'type': 'function'}, {'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'function': {'arguments': '{"query": "What is the problem for seat23?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 227, 'total_tokens': 324, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6cf4c899-a551-418e-afbd-2ebe3dbde065-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the total responses under seat23 for Honda Civic?'}, 'id': 'call_FCbUUCsARZmGNS0ieZ21T9gB', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the male to female proportion for responses under seat23 for Honda Civic?'}, 'id': 'call_k7aZJs6nq5jYctuTs7JwqkVc', 'type': 'tool_call'}, {'name': 'Text2Cypher', 'args': {'query': 'What is the problem for seat23?'}, 'id': 'call_MaTspdXgSzi2zSdTOk7xM1uJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 227, 'output_tokens': 97, 'total_tokens': 324})], tool_call_id='call_MaTspdXgSzi2zSdTOk7xM1uJ')]
# params:  {'query': 'What is the problem for seat23?'}
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What is the problem for seat23?\', \'result\': [{\'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'\\nMATCH (p:Problem {id: "SEAT23"})\\nRETURN p.problem AS problem\\n\'}]}'}], 'cypher': ['\nMATCH (p:Problem {id: "SEAT23"})\nRETURN p.problem AS problem\n'], 'cypher_result': [{'problem': 'SEAT23: Seat materials scuff/soil easily'}]}
#
# > router
# next action:  tool='final_answer' tool_input='' log='No more actions to perform. Moving to summarization step.'
# final_answer
# {'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the total responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses\\nRETURN totalResponses, problem\\n\'}]}'}, {'Text2Cypher', '{\'query\': \'What is the male to female proportion for responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'males\': 7, \'females\': 3, \'maleToFemaleRatio\': 2.3333333333333335, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \\nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\\n\'}]}'}, {'Text2Cypher', '{\'query\': \'What is the problem for seat23?\', \'result\': [{\'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'\\nMATCH (p:Problem {id: "SEAT23"})\\nRETURN p.problem AS problem\\n\'}]}'}], 'cypher': ['cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses\nRETURN totalResponses, problem\n', 'cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\n', '\nMATCH (p:Problem {id: "SEAT23"})\nRETURN p.problem AS problem\n'], 'cypher_result': [{'totalResponses': 10, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'totalResponses': 10, 'males': 7, 'females': 3, 'maleToFemaleRatio': 2.3333333333333335, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'problem': 'SEAT23: Seat materials scuff/soil easily'}], 'input': 'What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?', 'sub_questions': ['What are the total responses under seat23 for Honda Civic?', 'What is the male to female proportion for responses under seat23 for Honda Civic?', 'What is the problem for seat23?'], 'chat_history': []}
# > final_answer
# {'input': 'What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?', 'sub_questions': ['What are the total responses under seat23 for Honda Civic?', 'What is the male to female proportion for responses under seat23 for Honda Civic?', 'What is the problem for seat23?'], 'chat_history': [], 'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the total responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses\\nRETURN totalResponses, problem\\n\'}]}'}, {'Text2Cypher', '{\'query\': \'What is the male to female proportion for responses under seat23 for Honda Civic?\', \'result\': [{\'totalResponses\': 10, \'males\': 7, \'females\': 3, \'maleToFemaleRatio\': 2.3333333333333335, \'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'cypher\\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \\nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\\n\'}]}'}, {'Text2Cypher', '{\'query\': \'What is the problem for seat23?\', \'result\': [{\'problem\': \'SEAT23: Seat materials scuff/soil easily\'}], \'intermediate_steps\': [{\'query\': \'\\nMATCH (p:Problem {id: "SEAT23"})\\nRETURN p.problem AS problem\\n\'}]}'}], 'cypher': ['cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses\nRETURN totalResponses, problem\n', 'cypher\nMATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})\nWITH p.problem AS problem, COUNT(v) AS totalResponses, \nSUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,\nSUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females\nRETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem\n', '\nMATCH (p:Problem {id: "SEAT23"})\nRETURN p.problem AS problem\n'], 'cypher_result': [{'totalResponses': 10, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'totalResponses': 10, 'males': 7, 'females': 3, 'maleToFemaleRatio': 2.3333333333333335, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'problem': 'SEAT23: Seat materials scuff/soil easily'}]}

# %%
res["agent_outcome"].display()
# Out:
# Question:
# What are the total responses under seat23 for honda civic, what is the male to female proportion for these responses and what is the problem for seat23?
#
# Sub Questions:
# What are the total responses under seat23 for Honda Civic?
# What is the male to female proportion for responses under seat23 for Honda Civic?
# What is the problem for seat23?
#
#
# Cypher:
# cypher
# MATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})
# WITH p.problem AS problem, COUNT(v) AS totalResponses
# RETURN totalResponses, problem
#
#
# cypher
# MATCH (p:Problem {id: "SEAT23"})<-[:HAS_PROBLEM]-(v:Verbatim {make: "Honda", model: "Civic"})
# WITH p.problem AS problem, COUNT(v) AS totalResponses,
# SUM(CASE WHEN v.gender = "Male" THEN 1 ELSE 0 END) AS males,
# SUM(CASE WHEN v.gender = "Female" THEN 1 ELSE 0 END) AS females
# RETURN totalResponses, males, females, toFloat(males) /  (CASE WHEN females = 0 THEN 1 ELSE females END) AS maleToFemaleRatio, problem
#
#
#
# MATCH (p:Problem {id: "SEAT23"})
# RETURN p.problem AS problem
#
#
#
#
# Cypher Result:
# [{'totalResponses': 10, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'totalResponses': 10, 'males': 7, 'females': 3, 'maleToFemaleRatio': 2.3333333333333335, 'problem': 'SEAT23: Seat materials scuff/soil easily'}, {'problem': 'SEAT23: Seat materials scuff/soil easily'}]
#
# Final Response:
# - Total responses under SEAT23: 10
# - Male to female proportion: 2.33 (7 males, 3 females)
# - Problem for SEAT23: Seat materials scuff/soil easily

# %%
res = agent.invoke({"input": "What are the top 5 problems about seats for each age buckets for men over the age of 53?", "chat_history": list()})
# Out:
# > run_agent
# initial data:  {'input': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?', 'sub_questions': None, 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'cypher': None, 'cypher_result': None}
# tool='Text2Cypher' tool_input={'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age buckets for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 217, 'total_tokens': 254, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bfe33060-a4f6-4037-af8a-91bf2a48acdc-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, 'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 217, 'output_tokens': 37, 'total_tokens': 254})] tool_call_id='call_m0nqHlpmbz75CIiZ7WOTdjpx'
# > router
# next action:  tool='Text2Cypher' tool_input={'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age buckets for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 217, 'total_tokens': 254, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bfe33060-a4f6-4037-af8a-91bf2a48acdc-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, 'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 217, 'output_tokens': 37, 'total_tokens': 254})] tool_call_id='call_m0nqHlpmbz75CIiZ7WOTdjpx'
# Text2Cypher
# {'agent_outcome': [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age buckets for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 217, 'total_tokens': 254, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bfe33060-a4f6-4037-af8a-91bf2a48acdc-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, 'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 217, 'output_tokens': 37, 'total_tokens': 254})], tool_call_id='call_m0nqHlpmbz75CIiZ7WOTdjpx')], 'sub_questions': ['What are the top 5 problems about seats for each age buckets for men over the age of 53?'], 'input': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?', 'chat_history': [], 'intermediate_steps': []}
# > text2cypher node
# agent action:  1 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age buckets for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 217, 'total_tokens': 254, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_52a7f40b0b', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-bfe33060-a4f6-4037-af8a-91bf2a48acdc-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}, 'id': 'call_m0nqHlpmbz75CIiZ7WOTdjpx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 217, 'output_tokens': 37, 'total_tokens': 254})], tool_call_id='call_m0nqHlpmbz75CIiZ7WOTdjpx')]
# params:  {'query': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?'}
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the top 5 problems about seats for each age buckets for men over the age of 53?\', \'result\': [{\'ageBucket\': \'55-59\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises\', \'SEAT18: Seat - Excessively uncomfortable\', \'SEAT97: Other Seat Problem(s)\', \'SEAT16: Seat belt bangs/flaps when not in use\'], \'total\': [5, 4, 4, 3, 2], \'responses\': [[\'I’m 6’3”. A couple more inches of leg room would be nice.\', \'I am 6 feet tall.. Not a good fit with longer legs\', \'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives\', \'Should have more front tilt range for me\', \'\'], [\'Squeaks when exiting car.\', \'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.\', \'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.\', \'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.\'], [\'Not enough padding, uncomfortable on longer trips\', \'Hard seats, not comfortable at all.\', \'Front and back passenger seats are not very comfortable for long drives\', \'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.\'], [\'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.\', \'Missing the feature to adjust passanger seat height\', \'both front seat belts make vibration/ rattling noises at the hight adjustment lever\'], [\'seat belt clip bangs to the driver seat  bottom plastic edge when moving, specially when car bounces due to road conditions.\', \'Driver side does not fully retract. not all the times. only happened a few times/\']]}, {\'ageBucket\': \'60-64\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT22: Seat material imperfection\', \'SEAT09: Heated seats - Do not heat fast enough/maintain temperature\', \'SEAT08: Memory seats - Controls DTU/poorly located\', \'SEAT03: Seat adjustment - Controls DTU\'], \'total\': [8, 3, 3, 3, 2], \'responses\': [[\'can adjust the height so it feels like you are sitting in a hole.\', \'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\\\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\\\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!\', "My wife is usually in the passenger seat and doesn\'t like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", \'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust\', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn\'t work?", \'Not enough leg room\', \'passenger side should have adjustments equal to driver side, height and lumber should be included\', "I have a short torso, so I wish seat adjusted a little higher. I\'m used to driving pick up trucks so it just feels I am sitting too low, but I\'m getting used to it already."], [\'Poor stretch and stiching\', \'Leather seat contains ripples\', \'\ ...
#
# > router
# next action:  tool='final_answer' tool_input='' log='No more actions to perform. Moving to summarization step.'
# final_answer
# {'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the top 5 problems about seats for each age buckets for men over the age of 53?\', \'result\': [{\'ageBucket\': \'55-59\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises\', \'SEAT18: Seat - Excessively uncomfortable\', \'SEAT97: Other Seat Problem(s)\', \'SEAT16: Seat belt bangs/flaps when not in use\'], \'total\': [5, 4, 4, 3, 2], \'responses\': [[\'I’m 6’3”. A couple more inches of leg room would be nice.\', \'I am 6 feet tall.. Not a good fit with longer legs\', \'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives\', \'Should have more front tilt range for me\', \'\'], [\'Squeaks when exiting car.\', \'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.\', \'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.\', \'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.\'], [\'Not enough padding, uncomfortable on longer trips\', \'Hard seats, not comfortable at all.\', \'Front and back passenger seats are not very comfortable for long drives\', \'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.\'], [\'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.\', \'Missing the feature to adjust passanger seat height\', \'both front seat belts make vibration/ rattling noises at the hight adjustment lever\'], [\'seat belt clip bangs to the driver seat  bottom plastic edge when moving, specially when car bounces due to road conditions.\', \'Driver side does not fully retract. not all the times. only happened a few times/\']]}, {\'ageBucket\': \'60-64\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT22: Seat material imperfection\', \'SEAT09: Heated seats - Do not heat fast enough/maintain temperature\', \'SEAT08: Memory seats - Controls DTU/poorly located\', \'SEAT03: Seat adjustment - Controls DTU\'], \'total\': [8, 3, 3, 3, 2], \'responses\': [[\'can adjust the height so it feels like you are sitting in a hole.\', \'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\\\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\\\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!\', "My wife is usually in the passenger seat and doesn\'t like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", \'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust\', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn\'t work?", \'Not enough leg room\', \'passenger side should have adjustments equal to driver side, height and lumber should be included\', "I have a short torso, so I wish seat adjusted a little higher. I\'m used to driving pick up trucks so it just feels ...
# > final_answer
# {'input': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?', 'sub_questions': ['What are the top 5 problems about seats for each age buckets for men over the age of 53?'], 'chat_history': [], 'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'query\': \'What are the top 5 problems about seats for each age buckets for men over the age of 53?\', \'result\': [{\'ageBucket\': \'55-59\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises\', \'SEAT18: Seat - Excessively uncomfortable\', \'SEAT97: Other Seat Problem(s)\', \'SEAT16: Seat belt bangs/flaps when not in use\'], \'total\': [5, 4, 4, 3, 2], \'responses\': [[\'I’m 6’3”. A couple more inches of leg room would be nice.\', \'I am 6 feet tall.. Not a good fit with longer legs\', \'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives\', \'Should have more front tilt range for me\', \'\'], [\'Squeaks when exiting car.\', \'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.\', \'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.\', \'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.\'], [\'Not enough padding, uncomfortable on longer trips\', \'Hard seats, not comfortable at all.\', \'Front and back passenger seats are not very comfortable for long drives\', \'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.\'], [\'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.\', \'Missing the feature to adjust passanger seat height\', \'both front seat belts make vibration/ rattling noises at the hight adjustment lever\'], [\'seat belt clip bangs to the driver seat  bottom plastic edge when moving, specially when car bounces due to road conditions.\', \'Driver side does not fully retract. not all the times. only happened a few times/\']]}, {\'ageBucket\': \'60-64\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT22: Seat material imperfection\', \'SEAT09: Heated seats - Do not heat fast enough/maintain temperature\', \'SEAT08: Memory seats - Controls DTU/poorly located\', \'SEAT03: Seat adjustment - Controls DTU\'], \'total\': [8, 3, 3, 3, 2], \'responses\': [[\'can adjust the height so it feels like you are sitting in a hole.\', \'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\\\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\\\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!\', "My wife is usually in the passenger seat and doesn\'t like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", \'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust\', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn\'t work?", \'Not enough ...

# %%
res.get("agent_outcome").display()
# Out:
# Question:
# What are the top 5 problems about seats for each age buckets for men over the age of 53?
#
# Sub Questions:
# What are the top 5 problems about seats for each age buckets for men over the age of 53?
#
#
# Cypher:
#
# MATCH (v:Verbatim)-[:HAS_PROBLEM]->(p:Problem)
# WHERE toLower(p.problem) CONTAINS 'seat' AND v.gender = "Male" AND v.minAge > 53 AND v.ageBucket IS NOT NULL
# WITH v.ageBucket AS ageBucket, p.problem AS problem, COLLECT(v.verbatim) AS responses
# WITH ageBucket, problem, SIZE(responses) AS total, responses
# WITH *
# ORDER BY ageBucket, total DESC
# WITH ageBucket, COLLECT(problem) AS problems, COLLECT(total) AS totals, COLLECT(responses) AS responsesList
# RETURN ageBucket, problems[..5] AS problem, totals[..5] AS total, responsesList[..5] AS responses
# LIMIT 5
#
#
#
#
# Cypher Result:
# [{'ageBucket': '55-59', 'problem': ['SEAT04: Seats have insufficient range of adjustment', 'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises', 'SEAT18: Seat - Excessively uncomfortable', 'SEAT97: Other Seat Problem(s)', 'SEAT16: Seat belt bangs/flaps when not in use'], 'total': [5, 4, 4, 3, 2], 'responses': [['I’m 6’3”. A couple more inches of leg room would be nice.', 'I am 6 feet tall.. Not a good fit with longer legs', 'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives', 'Should have more front tilt range for me', ''], ['Squeaks when exiting car.', 'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.', 'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.', 'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.'], ['Not enough padding, uncomfortable on longer trips', 'Hard seats, not comfortable at all.', 'Front and back passenger seats are not very comfortable for long drives', 'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.'], ['No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.', 'Missing the feature to adjust passanger seat height', 'both front seat belts make vibration/ rattling noises at the hight adjustment lever'], ['seat belt clip bangs to the driver seat  bottom plastic edge when moving, specially when car bounces due to road conditions.', 'Driver side does not fully retract. not all the times. only happened a few times/']]}, {'ageBucket': '60-64', 'problem': ['SEAT04: Seats have insufficient range of adjustment', 'SEAT22: Seat material imperfection', 'SEAT09: Heated seats - Do not heat fast enough/maintain temperature', 'SEAT08: Memory seats - Controls DTU/poorly located', 'SEAT03: Seat adjustment - Controls DTU'], 'total': [8, 3, 3, 3, 2], 'responses': [['can adjust the height so it feels like you are sitting in a hole.', 'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!', "My wife is usually in the passenger seat and doesn't like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", 'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn't work?", 'Not enough leg room', 'passenger side should have adjustments equal to driver side, height and lumber should be included', "I have a short torso, so I wish seat adjusted a little higher. I'm used to driving pick up trucks so it just feels I am sitting too low, but I'm getting used to it already."], ['Poor stretch and stiching', 'Leather seat contains ripples', ''], ["Seats do not get warm enough or stay warm when compared to other vehicles I've owed.", 'It seems like on 2 of 3 that it barely gets warm', ''], ['', 'Pretty difficult to use. I have to go to the dealer to set it off.', 'Always reverts back to setting on ...
#
# Final Response:
# - **Age 55-59:**
#   - Insufficient range of seat adjustment
#   - Seat squeaks/rattles/loose/abnormal noises
#   - Excessively uncomfortable seats
#   - General seat problems
#   - Seat belt bangs/flaps when not in use
#
# - **Age 60-64:**
#   - Insufficient range of seat adjustment
#   - Seat material imperfections
#   - Heated seats do not heat fast enough/maintain temperature
#   - Memory seats controls difficult to use/poorly located
#   - Seat adjustment controls difficult to use
#
# - **Age 65-69:**
#   - Insufficient range of seat adjustment
#   - Seat material imperfections
#   - Seat materials scuff/soil easily
#   - Seat belt uncomfortable
#   - Seat belt bangs/flaps when not in use
#
# - **Age >=70:**
#   - Insufficient range of seat adjustment
#   - Excessively uncomfortable seats
#   - General seat problems
#   - Cooled/ventilated seats do not cool fast enough/maintain temperature/excessively noisy
#   - Seat belt uncomfortable

# %%
res = agent.invoke({"input": "Please summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. As an output, I want the summary, corresponding categories and their verbatims", "chat_history": list()})
# Out:
# > run_agent
# initial data:  {'input': 'Please summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. As an output, I want the summary, corresponding categories and their verbatims', 'sub_questions': None, 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'cypher': None, 'cypher_result': None}
# tool='Text2Cypher' tool_input={'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'} log="\nInvoking: `Text2Cypher` with `{'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Oyc5hges6LhFFHYPXtuMdLKk', 'function': {'arguments': '{"query":"summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims."}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 238, 'total_tokens': 299, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_e375328146', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-9f4588d2-c744-4547-9dbc-e17070cd6a54-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}, 'id': 'call_Oyc5hges6LhFFHYPXtuMdLKk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 238, 'output_tokens': 61, 'total_tokens': 299})] tool_call_id='call_Oyc5hges6LhFFHYPXtuMdLKk'
# > router
# > text2cypher node
# agent action:  1 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}, log="\nInvoking: `Text2Cypher` with `{'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Oyc5hges6LhFFHYPXtuMdLKk', 'function': {'arguments': '{"query":"summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims."}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 238, 'total_tokens': 299, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_e375328146', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-9f4588d2-c744-4547-9dbc-e17070cd6a54-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}, 'id': 'call_Oyc5hges6LhFFHYPXtuMdLKk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 238, 'output_tokens': 61, 'total_tokens': 299})], tool_call_id='call_Oyc5hges6LhFFHYPXtuMdLKk')]
# params:  {'query': 'summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'}
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'result\': [{\'category\': \'Exterior\', \'problem\': "EXT10: Trunk/hatch/tailgate - Touch-free sensor doesn\'t work consistently/DTU", \'verbatims\': [\'when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss.\', \'foot release does not work consistently\', \'At times, the leg action does not close the tailgate.  Other times, when i am loading/unloading the trunk and have my feet under the vehicle, the tailgate closes.\', \'My wife and I have not found a consistent place to activate the sensor. We move our feet all along the rear of the car and sometimes it opens others it doesn’t.\', \'this feature doesnt work consistently\', \'Using my leg to open the back tailgate had not been reliable.\', \'Haven’t been able to get this feature to work consistently.\', \'sensor to open tailgate with foot does not work a good amount of the time\', "Hatch touch-free sensor doesn\'t work consistently.  Perhaps a marking in sight would help indicate where the sensor is located.", \'When placing my foot under the sensor, it does not open/close. If it read a larger area it would be easier to use! Otherwise I use the button\', \'Wave foot under sensor multiple times and unable to open.\', \'I can’t figure out this feature.\', "Trunck/hatch/tailgate touch free sensor doesn\'t work consistently. I have to continually place my foot under the tailgate to activate. Sometimes it doesn\'t activate so I use the tailgate button to open.", \'Sometimes it just does not work.\', \'My foot underneath doesn’t always open the trunk. I sometimes have to hit the button in order for it to open.\', \'Putting your foot under the back of the trunk only opens the lift gate 50% of the time\', \'Touch free sensor doesn’t seem to be responsive. I’ve had to wave my foot around it three or four times and after a four second delay, it triggers the mechanism to open the hatch\', \'When I kick under the tail gate there ocassions when it doesn’t open\', \'\', "doesn\'t work", \'Works some times\', \'Hard to locate it and it takes several times to get it to work\', "The location of the latch.  You have to be precise in touching the latch or it won\'t open.", \'Getting used to using this feature. I may not have my foot in the correct location to activate the hatch.\']}], \'cypher\': ["MATCH (q:Question{id: 10})<-[:HAS_QUESTION]-(v:Verbatim)\\n  WHERE v.model=\'RDX\'\\nWITH v.verbatim AS verbatim, v\\nMATCH (v)-[:HAS_PROBLEM]->(p:Problem)-[:HAS_CATEGORY]->(c:Category)\\nRETURN c.id AS category, p.problem AS problem, COLLECT(verbatim) AS verbatims\\nORDER BY category"]}'}], 'cypher': ["MATCH (q:Question{id: 10})<-[:HAS_QUESTION]-(v:Verbatim)\n  WHERE v.model='RDX'\nWITH v.verbatim AS verbatim, v\nMATCH (v)-[:HAS_PROBLEM]->(p:Problem)-[:HAS_CATEGORY]->(c:Category)\nRETURN c.id AS category, p.problem AS problem, COLLECT(verbatim) AS verbatims\nORDER BY category"], 'cypher_result': [{'category': 'Exterior', 'problem': "EXT10: Trunk/hatch/tailgate - Touch-free sensor doesn't work consistently/DTU", 'verbatims': ['when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss.', 'foot release does not work consistently', 'At times, the leg action does not close the tailgate.  Other times, when i am loading/unloading the trunk and have my feet under the vehicle, the tailgate closes.', 'My wife and I have not found a consistent place to activate the sensor. We move our feet all along the rear of the car and sometimes it opens others it doesn’t.', 'this feature doesnt work consistently', 'Using my leg to open the back tailgate had not been reliable.', 'Haven’t been able to get this feature to work consistently.', 'sensor to open tailgate with foot does not work a good amount of the time', "Hatch touch-free sensor doesn't work consistently.  Perhaps a marking in sight would help indicate where the sensor is located.", 'When placing my  ...
#
# > router
# > final_answer
# {'input': 'Please summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. As an output, I want the summary, corresponding categories and their verbatims', 'sub_questions': ['summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.'], 'chat_history': [], 'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'result\': [{\'category\': \'Exterior\', \'problem\': "EXT10: Trunk/hatch/tailgate - Touch-free sensor doesn\'t work consistently/DTU", \'verbatims\': [\'when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss.\', \'foot release does not work consistently\', \'At times, the leg action does not close the tailgate.  Other times, when i am loading/unloading the trunk and have my feet under the vehicle, the tailgate closes.\', \'My wife and I have not found a consistent place to activate the sensor. We move our feet all along the rear of the car and sometimes it opens others it doesn’t.\', \'this feature doesnt work consistently\', \'Using my leg to open the back tailgate had not been reliable.\', \'Haven’t been able to get this feature to work consistently.\', \'sensor to open tailgate with foot does not work a good amount of the time\', "Hatch touch-free sensor doesn\'t work consistently.  Perhaps a marking in sight would help indicate where the sensor is located.", \'When placing my foot under the sensor, it does not open/close. If it read a larger area it would be easier to use! Otherwise I use the button\', \'Wave foot under sensor multiple times and unable to open.\', \'I can’t figure out this feature.\', "Trunck/hatch/tailgate touch free sensor doesn\'t work consistently. I have to continually place my foot under the tailgate to activate. Sometimes it doesn\'t activate so I use the tailgate button to open.", \'Sometimes it just does not work.\', \'My foot underneath doesn’t always open the trunk. I sometimes have to hit the button in order for it to open.\', \'Putting your foot under the back of the trunk only opens the lift gate 50% of the time\', \'Touch free sensor doesn’t seem to be responsive. I’ve had to wave my foot around it three or four times and after a four second delay, it triggers the mechanism to open the hatch\', \'When I kick under the tail gate there ocassions when it doesn’t open\', \'\', "doesn\'t work", \'Works some times\', \'Hard to locate it and it takes several times to get it to work\', "The location of the latch.  You have to be precise in touching the latch or it won\'t open.", \'Getting used to using this feature. I may not have my foot in the correct location to activate the hatch.\']}], \'cypher\': ["MATCH (q:Question{id: 10})<-[:HAS_QUESTION]-(v:Verbatim)\\n  WHERE v.model=\'RDX\'\\nWITH v.verbatim AS verbatim, v\\nMATCH (v)-[:HAS_PROBLEM]->(p:Problem)-[:HAS_CATEGORY]->(c:Category)\\nRETURN c.id AS category, p.problem AS problem, COLLECT(verbatim) AS verbatims\\nORDER BY category"]}'}], 'cypher': ["MATCH (q:Question{id: 10})<-[:HAS_QUESTION]-(v:Verbatim)\n  WHERE v.model='RDX'\nWITH v.verbatim AS verbatim, v\nMATCH (v)-[:HAS_PROBLEM]->(p:Problem)-[:HAS_CATEGORY]->(c:Category)\nRETURN c.id AS category, p.problem AS problem, COLLECT(verbatim) AS verbatims\nORDER BY category"], 'cypher_result': [{'category': 'Exterior', 'problem': "EXT10: Trunk/hatch/tailgate - Touch-free sensor doesn't work consistently/DTU", 'verbatims': ['when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss.', 'foot release does not work consistently', 'At times, the leg action does not close the tailgate.  Other times, when i am loading/unloading the trunk and have my feet under the ...

# %%
res.get("agent_outcome").display()
# Out:
# Question:
# Please summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. As an output, I want the summary, corresponding categories and their verbatims
#
# Sub Questions:
# summarize the verbatims for 2023 RDX for question 010 Trunk/TG Touch-Free Sensor DTU and create categories for the problems. Provide the summary, corresponding categories, and their verbatims.
#
#
# Cypher:
# MATCH (q:Question{id: 10})<-[:HAS_QUESTION]-(v:Verbatim)
#   WHERE v.model='RDX'
# WITH v.verbatim AS verbatim, v
# MATCH (v)-[:HAS_PROBLEM]->(p:Problem)-[:HAS_CATEGORY]->(c:Category)
# RETURN c.id AS category, p.problem AS problem, COLLECT(verbatim) AS verbatims
# ORDER BY category
#
#
#
# Cypher Result:
# [{'category': 'Exterior', 'problem': "EXT10: Trunk/hatch/tailgate - Touch-free sensor doesn't work consistently/DTU", 'verbatims': ['when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss.', 'foot release does not work consistently', 'At times, the leg action does not close the tailgate.  Other times, when i am loading/unloading the trunk and have my feet under the vehicle, the tailgate closes.', 'My wife and I have not found a consistent place to activate the sensor. We move our feet all along the rear of the car and sometimes it opens others it doesn’t.', 'this feature doesnt work consistently', 'Using my leg to open the back tailgate had not been reliable.', 'Haven’t been able to get this feature to work consistently.', 'sensor to open tailgate with foot does not work a good amount of the time', "Hatch touch-free sensor doesn't work consistently.  Perhaps a marking in sight would help indicate where the sensor is located.", 'When placing my foot under the sensor, it does not open/close. If it read a larger area it would be easier to use! Otherwise I use the button', 'Wave foot under sensor multiple times and unable to open.', 'I can’t figure out this feature.', "Trunck/hatch/tailgate touch free sensor doesn't work consistently. I have to continually place my foot under the tailgate to activate. Sometimes it doesn't activate so I use the tailgate button to open.", 'Sometimes it just does not work.', 'My foot underneath doesn’t always open the trunk. I sometimes have to hit the button in order for it to open.', 'Putting your foot under the back of the trunk only opens the lift gate 50% of the time', 'Touch free sensor doesn’t seem to be responsive. I’ve had to wave my foot around it three or four times and after a four second delay, it triggers the mechanism to open the hatch', 'When I kick under the tail gate there ocassions when it doesn’t open', '', "doesn't work", 'Works some times', 'Hard to locate it and it takes several times to get it to work', "The location of the latch.  You have to be precise in touching the latch or it won't open.", 'Getting used to using this feature. I may not have my foot in the correct location to activate the hatch.']}]
#
# Final Response:
# - **Summary**: The touch-free sensor for the trunk/hatch/tailgate in the 2023 RDX is inconsistent and unreliable. Users experience difficulty in activating the sensor, requiring multiple attempts or resorting to using the button instead. The sensor's location is unclear, leading to frustration and inefficient use.
#
# - **Categories and Verbatims**:
#   - **Inconsistent Activation**:
#     - "when I move my foot under sensor sometimes the tailgate opens and sometimes it does not. It seems to be hit or miss."
#     - "foot release does not work consistently"
#     - "Sometimes it just does not work."
#     - "My foot underneath doesn’t always open the trunk. I sometimes have to hit the button in order for it to open."
#     - "Putting your foot under the back of the trunk only opens the lift gate 50% of the time"
#     - "Works some times"
#   - **Difficult to Locate Sensor**:
#     - "My wife and I have not found a consistent place to activate the sensor. We move our feet all along the rear of the car and sometimes it opens others it doesn’t."
#     - "Haven’t been able to get this feature to work consistently."
#     - "sensor to open tailgate with foot does not work a good amount of the time"
#     - "Hatch touch-free sensor doesn't work consistently. Perhaps a marking in sight would help indicate where the sensor is located."
#     - "Hard to locate it and it takes several times to get it to work"
#     - "The location of the latch. You have to be precise in touching the latch or it won't open."
#     - "Getting used to using this feature. I may not have my foot in the correct location to activate the hatch."
#   - **Delayed or No Response**:
#     - "When placing my foot under the sensor, it does not open/close. If it read a larger area it would be easier to use! Otherwise I use the button"
#     - "Wave foot under sensor multiple times and unable to open."
#     - "I can’t figure out this feature."
#     - "Touch free sensor doesn’t seem to be responsive. I’ve had to wave my foot around it three or four times and after a four second delay, it triggers the mechanism to open the hatch"
#     - "When I kick under the tail gate there ocassions when it doesn’t open"
#     - "doesn't work"
#   - **General Frustration**:
#     - "Using my leg to open the back tailgate had not been reliable."
#     - "Trunck/hatch/tailgate touch free sensor doesn't work consistently. I have to continually place my foot under the tailgate to activate. Sometimes it doesn't activate so I use the tailgate button to open."

# %%
res = agent.invoke({"input": "What are the top 5 problems about seats for each age buckets for men over the age of 53?", "chat_history": []})
# Out:
# > run_agent
# initial data:  {'input': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?', 'sub_questions': None, 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'cypher': None, 'cypher_result': None}
# tool='Text2Cypher' tool_input={'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'} log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}`\n\n\n" message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_RkczxCKLKFESlWthnKEtAF2T', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age bucket for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 212, 'total_tokens': 249, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_3537616b13', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-82a8dca4-f46f-41ea-8b59-d360764d83da-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}, 'id': 'call_RkczxCKLKFESlWthnKEtAF2T', 'type': 'tool_call'}], usage_metadata={'input_tokens': 212, 'output_tokens': 37, 'total_tokens': 249})] tool_call_id='call_RkczxCKLKFESlWthnKEtAF2T'
# > router
# > text2cypher node
# agent action:  1 [ToolAgentAction(tool='Text2Cypher', tool_input={'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}, log="\nInvoking: `Text2Cypher` with `{'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_RkczxCKLKFESlWthnKEtAF2T', 'function': {'arguments': '{"query":"What are the top 5 problems about seats for each age bucket for men over the age of 53?"}', 'name': 'Text2Cypher'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 212, 'total_tokens': 249, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_3537616b13', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-82a8dca4-f46f-41ea-8b59-d360764d83da-0', tool_calls=[{'name': 'Text2Cypher', 'args': {'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}, 'id': 'call_RkczxCKLKFESlWthnKEtAF2T', 'type': 'tool_call'}], usage_metadata={'input_tokens': 212, 'output_tokens': 37, 'total_tokens': 249})], tool_call_id='call_RkczxCKLKFESlWthnKEtAF2T')]
# params:  {'query': 'What are the top 5 problems about seats for each age bucket for men over the age of 53?'}
# Failed to write data to connection ResolvedIPv4Address(('52.44.11.98', 7687)) (ResolvedIPv4Address(('52.44.11.98', 7687)))
# Failed to write data to connection IPv4Address(('p-6adb3c47-537b-0020.production-orch-0032.neo4j.io', 7687)) (ResolvedIPv4Address(('44.199.31.19', 7687)))
# Failed to write data to connection ResolvedIPv4Address(('50.16.105.214', 7687)) (ResolvedIPv4Address(('50.16.105.214', 7687)))
# Cypher attempt: 1
# {'intermediate_steps': [{'Text2Cypher', '{\'result\': [{\'ageBucket\': \'55-59\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'INFO20: Not enough power plugs/USB ports\', \'SEAT18: Seat - Excessively uncomfortable\', \'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises\', \'SEAT97: Other Seat Problem(s)\'], \'total\': [4, 4, 4, 4, 3], \'responses\': [[\'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives\', \'I am 6 feet tall.. Not a good fit with longer legs\', \'I’m 6’3”. A couple more inches of leg room would be nice.\', \'Should have more front tilt range for me\'], [\'Come on guys?! In todays family-EVERYONE HAS A DEVICE THAT NEEDS CHARGING!!! There should be more conveniently place usb ports for every seat.\', \'Could do with usb charging port for the back seats\', \'Could use some in back seat.\', \'It would be very helpful if the RTL model had plugs in the rear for passengers.  I do not believe it currently does.  Only the one/two on the dash and the ports in the center console, which are problematic for passengers to use from the back seat.\'], [\'Front and back passenger seats are not very comfortable for long drives\', \'Hard seats, not comfortable at all.\', \'Not enough padding, uncomfortable on longer trips\', \'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.\'], [\'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.\', \'Squeaks when exiting car.\', \'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.\', \'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.\'], [\'Missing the feature to adjust passanger seat height\', \'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.\', \'both front seat belts make vibration/ rattling noises at the hight adjustment lever\']]}, {\'ageBucket\': \'60-64\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT09: Heated seats - Do not heat fast enough/maintain temperature\', \'SEAT10: Cooled/ventilated seats - Do not cool fast enough/maintain temperature/excessively noisy\', \'SEAT22: Seat material imperfection\', \'SEAT23: Seat materials scuff/soil easily\'], \'total\': [8, 2, 2, 2, 2], \'responses\': [[\'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust\', "I have a short torso, so I wish seat adjusted a little higher. I\'m used to driving pick up trucks so it just feels I am sitting too low, but I\'m getting used to it already.", \'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\\\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\\\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!\', "My wife is usually in the passenger seat and doesn\'t like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", \'Not enough leg room\', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn\'t work?", \'can adjust the height so it feels lik ...
#
# > router
# > final_answer
# {'input': 'What are the top 5 problems about seats for each age buckets for men over the age of 53?', 'sub_questions': ['What are the top 5 problems about seats for each age bucket for men over the age of 53?'], 'chat_history': [], 'agent_outcome': [AgentAction(tool='final_answer', tool_input='', log='No more actions to perform. Moving to summarization step.')], 'intermediate_steps': [{'Text2Cypher', '{\'result\': [{\'ageBucket\': \'55-59\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'INFO20: Not enough power plugs/USB ports\', \'SEAT18: Seat - Excessively uncomfortable\', \'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises\', \'SEAT97: Other Seat Problem(s)\'], \'total\': [4, 4, 4, 4, 3], \'responses\': [[\'Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives\', \'I am 6 feet tall.. Not a good fit with longer legs\', \'I’m 6’3”. A couple more inches of leg room would be nice.\', \'Should have more front tilt range for me\'], [\'Come on guys?! In todays family-EVERYONE HAS A DEVICE THAT NEEDS CHARGING!!! There should be more conveniently place usb ports for every seat.\', \'Could do with usb charging port for the back seats\', \'Could use some in back seat.\', \'It would be very helpful if the RTL model had plugs in the rear for passengers.  I do not believe it currently does.  Only the one/two on the dash and the ports in the center console, which are problematic for passengers to use from the back seat.\'], [\'Front and back passenger seats are not very comfortable for long drives\', \'Hard seats, not comfortable at all.\', \'Not enough padding, uncomfortable on longer trips\', \'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.\'], [\'Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.\', \'Squeaks when exiting car.\', \'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.\', \'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.\'], [\'Missing the feature to adjust passanger seat height\', \'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.\', \'both front seat belts make vibration/ rattling noises at the hight adjustment lever\']]}, {\'ageBucket\': \'60-64\', \'problem\': [\'SEAT04: Seats have insufficient range of adjustment\', \'SEAT09: Heated seats - Do not heat fast enough/maintain temperature\', \'SEAT10: Cooled/ventilated seats - Do not cool fast enough/maintain temperature/excessively noisy\', \'SEAT22: Seat material imperfection\', \'SEAT23: Seat materials scuff/soil easily\'], \'total\': [8, 2, 2, 2, 2], \'responses\': [[\'How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust\', "I have a short torso, so I wish seat adjusted a little higher. I\'m used to driving pick up trucks so it just feels I am sitting too low, but I\'m getting used to it already.", \'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\\\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\\\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cush ...

# %%
res.get("agent_outcome").display()
# Out:
# Question:
# What are the top 5 problems about seats for each age buckets for men over the age of 53?
#
# Sub Questions:
# What are the top 5 problems about seats for each age bucket for men over the age of 53?
#
#
# Cypher:
# MATCH (v:Verbatim)-[:HAS_PROBLEM]->(p:Problem)
# WHERE toLower(v.verbatimText) CONTAINS 'seat' AND v.gender = 'Male' AND v.minAge > 53 AND v.ageBucket IS NOT NULL
# WITH v.ageBucket AS ageBucket, p.problem AS problem, COLLECT(v.verbatim) AS responses
# WITH ageBucket, problem, SIZE(responses) AS total, responses
# WITH * ORDER BY ageBucket, total DESC
# WITH ageBucket, COLLECT(problem) AS problems, COLLECT(total) AS totals, COLLECT(responses) AS responsesList
# RETURN ageBucket, problems[..5] AS problem, totals[..5] AS total, responsesList[..5] AS responses
# LIMIT 5
#
#
#
# Cypher Result:
# [{'ageBucket': '55-59', 'problem': ['SEAT04: Seats have insufficient range of adjustment', 'INFO20: Not enough power plugs/USB ports', 'SEAT18: Seat - Excessively uncomfortable', 'SEAT17: Seat - Squeaks/rattles/loose/abnormal noises', 'SEAT97: Other Seat Problem(s)'], 'total': [4, 4, 4, 4, 3], 'responses': [['Bottom seat cushion is on the short side. The end/length of the seat only reaches about 2inches shy of my knee making it uncomfortable on longer drives', 'I am 6 feet tall.. Not a good fit with longer legs', 'I’m 6’3”. A couple more inches of leg room would be nice.', 'Should have more front tilt range for me'], ['Come on guys?! In todays family-EVERYONE HAS A DEVICE THAT NEEDS CHARGING!!! There should be more conveniently place usb ports for every seat.', 'Could do with usb charging port for the back seats', 'Could use some in back seat.', 'It would be very helpful if the RTL model had plugs in the rear for passengers.  I do not believe it currently does.  Only the one/two on the dash and the ports in the center console, which are problematic for passengers to use from the back seat.'], ['Front and back passenger seats are not very comfortable for long drives', 'Hard seats, not comfortable at all.', 'Not enough padding, uncomfortable on longer trips', 'We had a 2011 odyssey, the seats were the most comfortable I have ever had in a vehicle.  The 2023 model has smaller, harder seats which are NOT comfortable like the earlier model.'], ['Rear passenger side seat squeaks when going over bumps.  If you collapse the seat the squeak goes away.  I am planning on taking it to the dealership so they can fix it.', 'Squeaks when exiting car.', 'The rattling  noise was coming from the inside of driver seat. Dealer fixed it having the seat removed, readjusted and tightened the loose seat part inside.', 'there is a squeak or rattle you hear when on bumpy road from the passenger side of the car.'], ['Missing the feature to adjust passanger seat height', 'No lumbar adjustment - needed.  Also, the armrest on the driver side is slopped toward the driver causing your arm to fall off.', 'both front seat belts make vibration/ rattling noises at the hight adjustment lever']]}, {'ageBucket': '60-64', 'problem': ['SEAT04: Seats have insufficient range of adjustment', 'SEAT09: Heated seats - Do not heat fast enough/maintain temperature', 'SEAT10: Cooled/ventilated seats - Do not cool fast enough/maintain temperature/excessively noisy', 'SEAT22: Seat material imperfection', 'SEAT23: Seat materials scuff/soil easily'], 'total': [8, 2, 2, 2, 2], 'responses': [['How hard would it be to put a full range seat like the drivers seat in the front passenger seat?   Did i not already pay enough for the elite trim.level? (Copied from SEAT97): Front passenger height....cant adjust', "I have a short torso, so I wish seat adjusted a little higher. I'm used to driving pick up trucks so it just feels I am sitting too low, but I'm getting used to it already.", 'It is understandable that cost control is important to balance car design and sales. Having said that, it would seem that adding a height adjustment to the passenger seat should not be a big deal. Honda\'s seat position tends to sit low (noticed this even on top-trim Civic, Accords, CR-Vs). My wife is 5\'2" and she barely able to view over the hood. Passenger also do need to feel confident when being driven around and difficulty seeing the front makes the experience uncomfortable. I am getting a raised seat cushion for my wife!', "My wife is usually in the passenger seat and doesn't like sitting higher than me the driver.  Would like height adjustment to lower the passenger seat.", 'Not enough leg room', "The passenger front seat only has a forward/back and recline feature-cannot raise or lower seat. Maybe it doesn't work?", 'can adjust the height so it feels like you are sitting in a hole.', 'passenger side should have adjustments equal to driver side, height and lumber should be included'], ['It seems lik ...
#
# Final Response:
# - **Age 55-59:**
#   - Insufficient range of seat adjustment, particularly height and legroom.
#   - Lack of sufficient power plugs/USB ports, especially in the back seats.
#   - Seats are excessively uncomfortable, particularly on long drives.
#   - Seats squeak, rattle, and have abnormal noises.
#   - Other seat-related problems, like lack of lumbar adjustment and armrest issues.
#
# - **Age 60-64:**
#   - Insufficient range of seat adjustment, especially the front passenger seat's height.
#   - Heated seats do not heat fast enough or maintain temperature.
#   - Cooled/ventilated seats do not cool fast enough and are noisy.
#   - Seat material imperfections like ripples and poor stitching.
#   - Seats scuff and soil easily, making them difficult to clean.
#
# - **Age 65-69:**
#   - Insufficient range of seat adjustment, particularly height and legroom.
#   - Seat belts are uncomfortable and cut across the neck.
#   - Not enough power plugs/USB ports, especially in the back seats.
#   - Seats scuff and soil easily, with suede holding too much dirt.
#   - Seat material imperfections like improperly attached leather and wrinkles.
#
# - **Age >=70:**
#   - Insufficient range of seat adjustment, especially height and legroom.
#   - Seats are excessively uncomfortable, with issues like firmness and lack of cushioning.
#   - Other seat-related problems, including software issues with seatbelt warnings and hard-to-use seat belts.
#   - Seat belts are uncomfortable and difficult to latch or reach.
#   - Seat adjustment controls are difficult to use and overly complicated.
